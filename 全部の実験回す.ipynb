# %%
# !python main.py --datase_name assist2009_akt --gpu_num 0

# %%
# !python main.py --datase_name assist2017_akt --gpu_num 0

# %%
# !python main.py --datase_name Eedi --gpu_num 0

# %%
# !python main.py --datase_name statics_skill_item --gpu_num 0

# %%
# !python main.py --datase_name kdd_skill_item --gpu_num 0
